# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

kashti=sns.load_dataset('titanic')
kashti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
kashti.to_csv('titanic.csv')

# %%
df=pd.read_csv('titanic.csv')
df
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...

# %%
df.dropna(inplace=True)
df
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 1             1         1       1  female  38.0      1      0  71.2833
# 3             3         1       1  female  35.0      1      0  53.1000
# 6             6         0       1    male  54.0      0      0  51.8625
# 10           10         1       3  female   4.0      1      1  16.7000
# 11           11         1       1  female  58.0      0      0  26.5500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 871         871         1       1  female  47.0      1      1  52.5542
# 872         872         0       1    male  33.0      0      0   5.0000
# 879         879         1       1  female  56.0      0      1  83.1583
# 887         887         1       1  female  19.0      0      0  30.0000
# 889         889         1       1    male  26.0      0      0  30.0000
#
#     embarked  class    who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.barplot(x="sex",y="age",hue='alive',data=df)
plt.show()

# %%
df.describe()
# Out:
#        Unnamed: 0    survived      pclass         age       sibsp       parch  \
# count  182.000000  182.000000  182.000000  182.000000  182.000000  182.000000
# mean   455.000000    0.675824    1.192308   35.623187    0.467033    0.478022
# std    247.584731    0.469357    0.516411   15.671615    0.645007    0.755869
# min      1.000000    0.000000    1.000000    0.920000    0.000000    0.000000
# 25%    262.250000    0.000000    1.000000   24.000000    0.000000    0.000000
# 50%    458.000000    1.000000    1.000000   36.000000    0.000000    0.000000
# 75%    677.000000    1.000000    1.000000   47.750000    1.000000    1.000000
# max    889.000000    1.000000    3.000000   80.000000    3.000000    4.000000
#
#              fare
# count  182.000000
# mean    78.919735
# std     76.490774
# min      0.000000
# 25%     29.700000
# 50%     57.000000
# 75%     90.000000
# max    512.329200

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df=pd.read_csv('titanic.csv')
new_df = df.drop(['embarked','embark_town','adult_male','parch','sibsp','deck','alone','pclass'],axis=1)
# print(new_df)
# print(df)

new_df
# Out:
#      Unnamed: 0  survived     sex   age     fare   class    who alive
# 0             0         0    male  22.0   7.2500   Third    man    no
# 1             1         1  female  38.0  71.2833   First  woman   yes
# 2             2         1  female  26.0   7.9250   Third  woman   yes
# 3             3         1  female  35.0  53.1000   First  woman   yes
# 4             4         0    male  35.0   8.0500   Third    man    no
# ..          ...       ...     ...   ...      ...     ...    ...   ...
# 886         886         0    male  27.0  13.0000  Second    man    no
# 887         887         1  female  19.0  30.0000   First  woman   yes
# 888         888         0  female   NaN  23.4500   Third  woman    no
# 889         889         1    male  26.0  30.0000   First    man   yes
# 890         890         0    male  32.0   7.7500   Third    man    no
#
# [891 rows x 8 columns]

# %%
new_df.groupby(['sex','class']).mean()
# Out:
#                Unnamed: 0  survived        age        fare
# sex    class
# female First   468.212766  0.968085  34.611765  106.125798
#        Second  442.105263  0.921053  28.722973   21.970121
#        Third   398.729167  0.500000  21.750000   16.118810
# male   First   454.729508  0.368852  41.281386   67.226127
#        Second  446.962963  0.157407  30.740707   19.741782
#        Third   454.515850  0.135447  26.507589   12.661633

# %%
new_df[new_df['age'] <18].mean()
# Out:
# C:\Users\ibila\AppData\Local\Temp\ipykernel_4428\3140820971.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[df['age'] <18].mean()
# Unnamed: 0    428.212389
# survived        0.539823
# pclass          2.584071
# age             9.041327
# sibsp           1.460177
# parch           1.053097
# fare           31.220798
# adult_male      0.159292
# alone           0.203540
# dtype: float64

# %%
new_df[new_df['age'] <18].groupby(['sex','class']).mean()
# Out:
#                Unnamed: 0  survived        age        fare
# sex    class
# female First   524.375000  0.875000  14.125000  104.083337
#        Second  368.250000  1.000000   8.333333   26.241667
#        Third   373.942857  0.542857   8.428571   18.727977
# male   First   525.500000  1.000000   8.230000  116.072900
#        Second  526.818182  0.818182   4.757273   25.659473
#        Third   436.953488  0.232558   9.963256   22.752523

# %%
print("abc.DEF".capitalize())
# Out:
# Abc.def

# %% [markdown]
# # Pandas Exercise

# %%
# importing pandas

import pandas as pd

# %%
# Read salaries.csv in pandas

sal = pd.read_csv('salaries.csv')
# Out:
# C:\Users\ibila\AppData\Local\Temp\ipykernel_664\422852143.py:3: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   sal = pd.read_csv('salaries.csv')

# %%
# Print the head of data frame sal

sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENaNCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# ...

# %%
#  Use .info method to find out how many entries are there

sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148648 non-null  object
#  2   JobTitle          148650 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(7), int64(2), object(4)
# memory usage: 14.7+ MB

# %%
# what is the average base pay

sal.BasePay.mean()
# Out:
# 66325.4488404877

# %%
# What is the Highest amount of overtimePay in the dataset

sal.OvertimePay.max()
# Out:
# 245131.88

# %%
# What is the Job Title of JOSEPH DRISCOLL ? 

sal[sal['EmployeeName'] == "JOSEPH DRISCOLL"]["JobTitle"]
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %%
#  How much does Joseph Driscoll make inlcuding benifits

print(sal[sal['EmployeeName']=="JOSEPH DRISCOLL"]['TotalPay'])
# Out:
# 24    270324.91
# Name: TotalPay, dtype: float64

# %%
# What is the name of highest paid person including benifits

# sal[sal['TotalPay'].max()]['EmployeeName']
sal[sal['TotalPayBenefits']==sal.TotalPayBenefits.max()]['EmployeeName']
# Out:
# 0    NATHANIEL FORD
# Name: EmployeeName, dtype: object

# %%
# What is the name of lowest paid person inlcuding benifits
sal[sal['TotalPayBenefits']==sal.TotalPayBenefits.min()]['EmployeeName']
# Out:
# 148653    Joe Lopez
# Name: EmployeeName, dtype: object

# %%
# What is the avg (mean) base pay of all employees per year 2011-2014
sal.groupby('Year').mean().BasePay
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %%
# How many Unique Job Titles are there 

sal['JobTitle'].nunique()
# Out:
# 2158

# %%
# What are the top 5 most common jobs ?
sal['JobTitle'].value_counts().head()
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %%
#  How many Job Titles were Respresented by only 1 person in 2013 ?

sum(sal[sal['Year']==2013]["JobTitle"].value_counts()==1)
# Out:
# 202

# %%
# How many people have chief in thier job title?

def chief_string(title):
    if "chief" in title.lower().split():
        return True
    else:
        return False
